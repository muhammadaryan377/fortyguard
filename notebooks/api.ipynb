# %%
from backend.app.core.config import settings

print("FortyGuard key loaded:", bool(settings.fortyguard_api_key))
print("Base URL:", settings.fortyguard_base_url)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from backend.app.core.config import settings
#       2
#       3 print("FortyGuard key loaded:", bool(settings.fortyguard_api_key))
#       4 print("Base URL:", settings.fortyguard_base_url)
#
# ModuleNotFoundError: No module named 'backend'
