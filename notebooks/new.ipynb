# %%
import time
import base64
from pathlib import Path

import requests
from IPython.display import display, Image, JSON
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       1 import time
#       2 import base64
#       3 from pathlib import Path
#       4
# ----> 5 import requests
#       6 from IPython.display import display, Image, JSON
#
# ModuleNotFoundError: No module named 'requests'

# %%
API_KEY = 6e1e095f0c683a0f3c6316217176953c

BASE_URL = "https://api.fortyguard.com/v1"

headers = {
    "api-key": API_KEY
}

# Test with a US location
payload = {
    "latitude": 40.7128,
    "longitude": -74.0060,
    "vertical_angle": 10.0,
    "horizontal_angle": 90.0,
    "back_view": False
}

payload
